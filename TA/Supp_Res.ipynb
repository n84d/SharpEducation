# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np

# %%
TICKER = 'TSLA'
INTERVAL='1h'

# set period based on interval
if INTERVAL == '1h':
    PERIOD = '730d'
else:
    PERIOD = 'max'

RANGE = .02
WINDOW = 5
DURATION = 20
HOLDING_PERIOD = 5

# what subsetion of that data are you interested in
LOOKBACK = 10000

def get_data(ticker=TICKER, lookback=LOOKBACK, interval=INTERVAL):

    # get data at interval you want
    df = yf.download(ticker, interval=interval, period=PERIOD)
    df.columns = df.columns.get_level_values(0)

    # reset the index to make plots prettier
    df = df.reset_index(drop=True)

    # only return the subset of data you are interested in
    return df.iloc[-lookback:, :]

def indendify_lows(df, window=WINDOW):
    
    df = df.copy()
    df['Trough'] = 0

    rolling_min = df['Low'].rolling(window, center=True).min()
    df['Trough'] = np.where(df['Low'] == rolling_min, 1, 0)

    return df

def identify_highs(df, window=WINDOW):

    df = df.copy()
    df['Peak'] = 0

    rolling_max = df['High'].rolling(window, center=True).max()
    df['Peak'] = np.where(df['High'] == rolling_max, 1, 0)

    return df

def identify_support(df, ticker=TICKER, duration=DURATION, range=RANGE):
    df = df.copy()
    df = df.reset_index(drop=True)

    # initialize empty support column
    df['Support'] = 0

    # get rows of all instances with troughs
    indices = df.index[df['Trough'] == 1]
    for i in indices:

        # cycle through all rows after your study duration length
        if i >= duration:

            # subset of information relating to what happened {DURATION} periods before you encountered your trough
            info = df.iloc[i-duration:i]
            range_max = info['Close'].values[-1] + (info['Close'].values[-1] * (range/2))
            range_min = info['Close'].values[-1] - (info['Close'].values[-1] * (range/2))

            print(f'Support Range from Index {i}: [{range_max}, {range_min}]')

            other_instance = info.iloc[:-1][info.iloc[:-1]['Trough'] == 1]
            instance_in_range = False

            for idx, trough_row in other_instance.iterrows():
                close_price = trough_row['Close']
                if range_min <= close_price <= range_max:
                    instance_in_range = True
                    print(f'Trough at index {idx} in within range. Support Confirmed!')
                else:
                    print(f'Trough at index {idx} in NOT within range.')

            # say we found support if 2 troughs appear within the specified range in the specified time period
            if instance_in_range:
                df.loc[i, 'Support'] = 1

    plt.figure()

    # Plot the closing price
    plt.plot(df.index, df['Close'], label='Close Price', color='white', linewidth=1.5)

    # Plot lows (troughs) with blue circles
    troughs = df[df['Trough'] == 1]
    plt.scatter(troughs.index, troughs['Low'], color='skyblue', label='Troughs', s=200, marker='o', edgecolors='black', zorder=4)

    # Plot confirmed support levels with orange downward triangles
    support_points = df[df['Support'] == 1]
    plt.scatter(support_points.index, support_points['Low'], color='orange', label='Support', s=200, marker='v', edgecolors='black', zorder=5)

    # Styling
    plt.title(f"{ticker} — Support Zone Detection", fontsize=16, color='orange')
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Price", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.2)
    plt.legend()
    plt.tight_layout()
    plt.gca().set_facecolor('#111')
    plt.gcf().patch.set_facecolor('#111')
    plt.tick_params(colors='white')

    plt.show()

    return df

def identify_resistance(df, ticker=TICKER, duration=DURATION, range=RANGE):
    df = df.copy()
    df = df.reset_index(drop=True)

    # initialize empty support column
    df['Resistance'] = 0

    # get rows of all instances with troughs
    indices = df.index[df['Peak'] == 1]
    for i in indices:

        # cycle through all rows after your study duration length
        if i >= duration:

            # subset of information relating to what happened {DURATION} periods before you encountered your trough
            info = df.iloc[i-duration:i]
            range_max = info['Close'].values[-1] + (info['Close'].values[-1] * (range/2))
            range_min = info['Close'].values[-1] - (info['Close'].values[-1] * (range/2))

            print(f'Resistance Range from Index {i}: [{range_max}, {range_min}]')

            other_instance = info.iloc[:-1][info.iloc[:-1]['Peak'] == 1]
            instance_in_range = False

            for idx, peak_row in other_instance.iterrows():
                close_price = peak_row['Close']
                if range_min <= close_price <= range_max:
                    instance_in_range = True
                    print(f'Peak at index {idx} in within range. Resistance Confirmed!')
                else:
                    print(f'Peak at index {idx} in NOT within range.')

            # say we found support if 2 troughs appear within the specified range in the specified time period
            if instance_in_range:
                df.loc[i, 'Resistance'] = 1

    plt.figure()

    plt.plot(df.index, df['Close'], label='Close Price', color='white', linewidth=1.5)

    # Peaks (salmon)
    peaks = df[df['Peak'] == 1]
    plt.scatter(peaks.index, peaks['High'], color='salmon', label='Peaks', s=100, marker='o', edgecolors='black', zorder=4)

    # Resistance (red)
    resistance_points = df[df['Resistance'] == 1]
    plt.scatter(resistance_points.index, resistance_points['High'], color='red', label='Resistance', s=150, marker='^', edgecolors='black', zorder=5)

    plt.title(f"{ticker} — Resistance Zones", fontsize=16, color='red')
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.grid(True, linestyle='--', alpha=0.2)
    plt.legend()
    plt.tight_layout()
    plt.gca().set_facecolor('#111')
    plt.gcf().patch.set_facecolor('#111')
    plt.tick_params(colors='white')

    plt.show()

    return df

def strategy(df, holding_period=HOLDING_PERIOD):
    df = df.copy()
    df['Strategy'] = 0

    support = df['Support'].to_numpy()
    resistance = df['Resistance'].to_numpy()
    close = df['Close'].to_numpy()
    strategy = np.zeros(len(df))

    for i in range(len(df)):
        # Support breakout → go short
        if support[i] == 1:
            support_level = close[i]
            for j in range(i + 1, len(df)):
                if close[j] <= support_level and j + 1 < len(df):
                    strategy[j + 1 : j + 1 + holding_period] = -1
                    break

        # Resistance breakout → go long
        if resistance[i] == 1:
            resistance_level = close[i]
            for j in range(i + 1, len(df)):
                if close[j] >= resistance_level and j + 1 < len(df):
                    strategy[j + 1 : j + 1 + holding_period] = 1
                    break


    df['Strategy'] = strategy
    return df

def plot_strategy_comparison(df, ticker=TICKER):
    df = df.copy()

    # Calculate returns
    df['Return'] = df['Close'].pct_change().fillna(0)
    df['Strategy_Return'] = df['Return'] * df['Strategy']

    # Calculate cumulative returns
    df['Cumulative_SPY'] = (1 + df['Return']).cumprod()
    df['Cumulative_Strategy'] = (1 + df['Strategy_Return']).cumprod()

    # Find entry points using NumPy logic
    strategy = df['Strategy'].to_numpy()
    entry_indices = np.where((strategy != 0) & (np.roll(strategy, 1) == 0))[0]

    # Plotting
    fig, ax = plt.subplots()
    ax.plot(df.index, df['Cumulative_SPY'], label='SPY (Buy & Hold)', color='gray', linewidth=2)
    ax.plot(df.index, df['Cumulative_Strategy'], label='Strategy', color='orange', linewidth=2)

    # Entry markers
    for idx in entry_indices:
        entry_type = strategy[idx]
        if entry_type == 1:
            ax.scatter(df.index[idx], df['Cumulative_Strategy'].iloc[idx],
                       color='lime', edgecolor='black', marker='^', s=100, label='Long Entry')
        elif entry_type == -1:
            ax.scatter(df.index[idx], df['Cumulative_Strategy'].iloc[idx],
                       color='red', edgecolor='black', marker='v', s=100, label='Short Entry')

    # De-duplicate legend
    handles, labels = ax.get_legend_handles_labels()
    seen = set()
    deduped = []
    for h, l in zip(handles, labels):
        if l not in seen:
            deduped.append((h, l))
            seen.add(l)
    ax.legend(*zip(*deduped))

    ax.set_title(f"{ticker} — Strategy vs SPY", fontsize=16, color='white')
    ax.set_xlabel("Date", fontsize=12)
    ax.set_ylabel("Cumulative Return", fontsize=12)
    ax.grid(True, linestyle='--', alpha=0.3)
    ax.set_facecolor('#111')
    fig.patch.set_facecolor('#111')
    ax.tick_params(colors='white')
    plt.tight_layout()
    plt.show()

def main():
    df = get_data()
    df = indendify_lows(df)
    df = identify_highs(df)
    df = identify_support(df)
    df = identify_resistance(df)
    df = strategy(df)
    df = plot_strategy_comparison(df)
    return df

df = main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Support Range from Index 22: [312.09, 305.91]
# Trough at index 4 in NOT within range.
# Trough at index 7 in NOT within range.
# Trough at index 11 in NOT within range.
# Support Range from Index 33: [290.8117892456055, 285.05313995361325]
# Trough at index 22 in NOT within range.
# Support Range from Index 45: [283.1518109130859, 277.5448443603516]
# Trough at index 33 in NOT within range.
# Support Range from Index 57: [296.76711517333985, 290.8905386352539]
# Trough at index 45 in NOT within range.
# Support Range from Index 63: [289.5838415527344, 283.8495080566406]
# Trough at index 45 in NOT within range.
# Trough at index 57 in NOT within range.
# Support Range from Index 78: [307.4406341552734, 301.3527008056641]
# Trough at index 63 in NOT within range.
# Support Range from Index 85: [304.2826889038086, 298.25728912353514]
# Trough at index 78 in NOT within range.
# Support Range from Index 91: [307.01811584472654, 300.93854919433596]
# Trough at index 78 in NOT within range.
# Trough at index 85 in within range. Support Confirmed!
# Support Range from Index 100: [296.5888980102539, 290.71585052490235]
# Trough at index 85 in NOT within range.
# Trough at index 91 in NOT within range.
# Support Range from Index 105: [299.6367135620117, 293.70331329345703]
# Trough at index 85 in NOT within range.
# Trough at index 91 in NOT within range.
# Trough at index 100 in within range. Support Confirmed!
# Support Range from Index 112: [292.88989013671875, 287.09009033203125]
# Trough at index 100 in NOT within range.
# Trough at index 105 in within range. Support Confirmed!
# Support Range from Index 118: [300.42787200927734, 294.4788052368164]
# Trough at index 100 in NOT within range.
# Trough at index 105 in NOT within range.
# Trough at index 112 in NOT within range.
# Support Range from Index 127: [300.4670169067383, 294.51717498779294]
# Trough at index 112 in NOT within range.
# Trough at index 118 in within range. Support Confirmed!
# Support Range from Index 131: [296.2430975341797, 290.3768975830078]
# Trough at index 112 in within range. Support Confirmed!
# Trough at index 118 in NOT within range.
# Trough at index 127 in within range. Support Confirmed!
# Support Range from Index 142: [284.4664938354492, 278.8334939575195]
# Trough at index 127 in NOT within range.
# Trough at index 131 in NOT within range.
# Support Range from Index 150: [282.0020913696289, 276.41789154052736]
# Trough at index 131 in NOT within range.
# Trough at index 142 in NOT within range.
# Support Range from Index 155: [279.13915069580077, 273.6116427612305]
# Trough at index 142 in NOT within range.
# Trough at index 150 in NOT within range.
# Support Range from Index 162: [275.8759457397461, 270.41305572509765]
# Trough at index 142 in NOT within range.
# Trough at index 150 in within range. Support Confirmed!
# Trough at index 155 in within range. Support Confirmed!
# Support Range from Index 175: [272.9323110961914, 267.5277108764648]
# Trough at index 155 in NOT within range.
# Trough at index 162 in NOT within range.
# Support Range from Index 182: [277.245, 271.755]
# Trough at index 162 in NOT within range.
# Trough at index 175 in NOT within range.
# Support Range from Index 185: [280.4264938354492, 274.87349395751954]
# Trough at index 175 in NOT within range.
# Trough at index 182 in within range. Support Confirmed!
# Support Range from Index 189: [286.5673110961914, 280.89271087646483]
# Trough at index 175 in NOT within range.
# Trough at index 182 in NOT within range.
# Trough at index 185 in NOT within range.
# Support Range from Index 205: [306.42391479492187, 300.35611450195313]
# Trough at index 185 in NOT within range.
# Trough at index 189 in NOT within range.
# Support Range from Index 212: [294.1625, 288.3375]
# Trough at index 205 in NOT within range.
# Support Range from Index 216: [295.58789825439453, 289.7346725463867]
# Trough at index 205 in NOT within range.
# Trough at index 212 in within range. Support Confirmed!
# Support Range from Index 222: [303.1110852050781, 297.1088854980469]
# Trough at index 205 in within range. Support Confirmed!
# Trough at index 212 in NOT within range.
# Trough at index 216 in NOT within range.
# Support Range from Index 231: [306.743762512207, 300.66962860107424]
# Trough at index 212 in NOT within range.
# Trough at index 216 in NOT within range.
# Trough at index 222 in NOT within range.
# Support Range from Index 238: [306.2623110961914, 300.19771087646484]
# Trough at index 222 in NOT within range.
# Trough at index 231 in NOT within range.
# Support Range from Index 241: [309.0197146606445, 302.9005123901367]
# Trough at index 222 in NOT within range.
# Trough at index 231 in NOT within range.
# Trough at index 238 in within range. Support Confirmed!
# Support Range from Index 245: [312.28190246582034, 306.09810241699216]
# Trough at index 231 in NOT within range.
# Trough at index 238 in NOT within range.
# Trough at index 241 in NOT within range.
# Support Range from Index 249: [311.40826232910155, 305.24176208496095]
# Trough at index 231 in NOT within range.
# Trough at index 238 in within range. Support Confirmed!
# Trough at index 241 in within range. Support Confirmed!
# Trough at index 245 in within range. Support Confirmed!
# Support Range from Index 253: [311.6254086303711, 305.45460845947264]
# Trough at index 238 in within range. Support Confirmed!
# Trough at index 241 in within range. Support Confirmed!
# Trough at index 245 in within range. Support Confirmed!
# Trough at index 249 in within range. Support Confirmed!
# Support Range from Index 260: [295.92494506835936, 290.06504516601564]
# Trough at index 241 in NOT within range.
# Trough at index 245 in NOT within range.
# Trough at index 249 in NOT within range.
# Trough at index 253 in NOT within range.
# Support Range from Index 263: [293.29782928466796, 287.4899514770508]
# Trough at index 245 in NOT within range.
# Trough at index 249 in NOT within range.
# Trough at index 253 in NOT within range.
# Trough at index 260 in within range. Support Confirmed!
# Support Range from Index 266: [291.37489013671876, 285.60509033203124]
# Trough at index 249 in NOT within range.
# Trough at index 253 in NOT within range.
# Trough at index 260 in within range. Support Confirmed!
# Trough at index 263 in within range. Support Confirmed!
# Support Range from Index 273: [278.0832864379883, 272.57668670654294]
# Trough at index 253 in NOT within range.
# Trough at index 260 in NOT within range.
# Trough at index 263 in NOT within range.
# Trough at index 266 in NOT within range.
# Support Range from Index 276: [278.93180603027344, 273.40840393066406]
# Trough at index 260 in NOT within range.
# Trough at index 263 in NOT within range.
# Trough at index 266 in within range. Support Confirmed!
# Trough at index 273 in NOT within range.
# Support Range from Index 279: [282.05260986328125, 276.46740966796875]
# Trough at index 260 in NOT within range.
# Trough at index 263 in NOT within range.
# Trough at index 266 in within range. Support Confirmed!
# Trough at index 273 in NOT within range.
# Trough at index 276 in within range. Support Confirmed!
# Support Range from Index 284: [281.9516036987305, 276.36840362548827]
# Trough at index 266 in within range. Support Confirmed!
# Trough at index 273 in NOT within range.
# Trough at index 276 in within range. Support Confirmed!
# Trough at index 279 in NOT within range.
# Support Range from Index 287: [285.8501889038086, 280.18978912353515]
# Trough at index 273 in within range. Support Confirmed!
# Trough at index 276 in NOT within range.
# Trough at index 279 in NOT within range.
# Trough at index 284 in NOT within range.
# Support Range from Index 301: [270.96279876708985, 265.5971987915039]
# Trough at index 284 in NOT within range.
# Trough at index 287 in NOT within range.
# Support Range from Index 311: [245.1674055480957, 240.31260543823242]
# Trough at index 301 in NOT within range.
# Support Range from Index 318: [251.14660369873047, 246.17340362548828]
# Trough at index 301 in NOT within range.
# Trough at index 311 in NOT within range.
# Support Range from Index 324: [236.52179260253905, 231.83819274902345]
# Trough at index 311 in NOT within range.
# Trough at index 318 in NOT within range.
# Support Range from Index 329: [243.11710678100587, 238.3029066467285]
# Trough at index 311 in within range. Support Confirmed!
# Trough at index 318 in NOT within range.
# Trough at index 324 in NOT within range.
# Support Range from Index 339: [225.08860061645507, 220.63140060424806]
# Trough at index 324 in NOT within range.
# Trough at index 329 in NOT within range.
# Support Range from Index 343: [225.30070739746094, 220.83930725097656]
# Trough at index 324 in NOT within range.
# Trough at index 329 in NOT within range.
# Trough at index 339 in within range. Support Confirmed!
# Support Range from Index 350: [225.16940246582033, 220.71060241699217]
# Trough at index 339 in within range. Support Confirmed!
# Trough at index 343 in NOT within range.
# Support Range from Index 357: [218.75589630126953, 214.42409637451172]
# Trough at index 339 in NOT within range.
# Trough at index 343 in NOT within range.
# Trough at index 350 in NOT within range.
# Support Range from Index 364: [219.33160369873048, 214.98840362548827]
# Trough at index 350 in NOT within range.
# Trough at index 357 in NOT within range.
# Support Range from Index 377: [207.90850616455077, 203.79150604248048]
# Trough at index 357 in NOT within range.
# Trough at index 364 in NOT within range.
# Support Range from Index 383: [220.60016036987304, 216.23184036254884]
# Trough at index 364 in NOT within range.
# Trough at index 377 in NOT within range.
# Support Range from Index 387: [221.19, 216.81]
# Trough at index 377 in NOT within range.
# Trough at index 383 in within range. Support Confirmed!
# Support Range from Index 390: [223.25039321899413, 218.8295933532715]
# Trough at index 377 in NOT within range.
# Trough at index 383 in within range. Support Confirmed!
# Trough at index 387 in within range. Support Confirmed!
# Support Range from Index 395: [222.32119506835937, 217.91879516601563]
# Trough at index 377 in NOT within range.
# Trough at index 383 in within range. Support Confirmed!
# Trough at index 387 in within range. Support Confirmed!
# Trough at index 390 in within range. Support Confirmed!
# Support Range from Index 399: [224.62399383544923, 220.17599395751952]
# Trough at index 383 in NOT within range.
# Trough at index 387 in within range. Support Confirmed!
# Trough at index 390 in NOT within range.
# Trough at index 395 in NOT within range.
# Support Range from Index 406: [209.27705184936522, 205.13295181274415]
# Trough at index 387 in NOT within range.
# Trough at index 390 in NOT within range.
# Trough at index 395 in NOT within range.
# Trough at index 399 in within range. Support Confirmed!
# Support Range from Index 413: [216.645, 212.355]
# Trough at index 395 in NOT within range.
# Trough at index 399 in NOT within range.
# Trough at index 406 in NOT within range.
# Support Range from Index 424: [222.62419815063475, 218.21579818725587]
# Trough at index 406 in NOT within range.
# Trough at index 413 in NOT within range.
# Support Range from Index 427: [224.63410369873046, 220.1859036254883]
# Trough at index 413 in NOT within range.
# Trough at index 424 in within range. Support Confirmed!
# Support Range from Index 433: [227.91660369873046, 223.4034036254883]
# Trough at index 413 in NOT within range.
# Trough at index 424 in NOT within range.
# Trough at index 427 in within range. Support Confirmed!
# Support Range from Index 441: [227.34473373413087, 222.8428578186035]
# Trough at index 424 in NOT within range.
# Trough at index 427 in within range. Support Confirmed!
# Trough at index 433 in within range. Support Confirmed!
# Support Range from Index 449: [225.96729568481445, 221.49269577026368]
# Trough at index 433 in within range. Support Confirmed!
# Trough at index 441 in NOT within range.
# Support Range from Index 454: [230.29040267944336, 225.73019668579101]
# Trough at index 441 in NOT within range.
# Trough at index 449 in within range. Support Confirmed!
# Support Range from Index 459: [231.19910369873048, 226.62090362548827]
# Trough at index 441 in NOT within range.
# Trough at index 449 in NOT within range.
# Trough at index 454 in within range. Support Confirmed!
# Support Range from Index 469: [217.00860061645508, 212.71140060424804]
# Trough at index 449 in NOT within range.
# Trough at index 454 in NOT within range.
# Trough at index 459 in NOT within range.
# Support Range from Index 480: [206.87830184936524, 202.78170181274413]
# Trough at index 469 in NOT within range.
# Support Range from Index 485: [201.83839630126954, 197.8415963745117]
# Trough at index 469 in NOT within range.
# Trough at index 480 in NOT within range.
# Support Range from Index 490: [199.0305975341797, 195.0893975830078]
# Trough at index 480 in NOT within range.
# Trough at index 485 in NOT within range.
# Support Range from Index 503: [181.83029876708986, 178.2296987915039]
# Trough at index 485 in NOT within range.
# Trough at index 490 in NOT within range.
# Support Range from Index 511: [192.51660919189453, 188.70439910888672]
# Trough at index 503 in NOT within range.
# Support Range from Index 518: [197.83880493164062, 193.92120483398438]
# Trough at index 503 in NOT within range.
# Trough at index 511 in NOT within range.
# Support Range from Index 524: [194.6269969177246, 190.77299697875978]
# Trough at index 511 in within range. Support Confirmed!
# Trough at index 518 in NOT within range.
# Support Range from Index 529: [196.59649383544922, 192.70349395751953]
# Trough at index 511 in NOT within range.
# Trough at index 518 in NOT within range.
# Trough at index 524 in NOT within range.
# Support Range from Index 533: [190.05311599731445, 186.28968795776368]
# Trough at index 518 in NOT within range.
# Trough at index 524 in NOT within range.
# Trough at index 529 in NOT within range.
# Support Range from Index 539: [188.8094024658203, 185.0706024169922]
# Trough at index 524 in NOT within range.
# Trough at index 529 in NOT within range.
# Trough at index 533 in within range. Support Confirmed!
# Support Range from Index 547: [180.1335061645508, 176.56650604248046]
# Trough at index 529 in NOT within range.
# Trough at index 533 in NOT within range.
# Trough at index 539 in NOT within range.
# Support Range from Index 560: [169.54869506835936, 166.19129516601564]
# Trough at index 547 in NOT within range.
# Support Range from Index 564: [170.98289321899415, 167.59709335327148]
# Trough at index 547 in NOT within range.
# Trough at index 560 in within range. Support Confirmed!
# Support Range from Index 570: [181.14854568481445, 177.56144577026367]
# Trough at index 560 in NOT within range.
# Trough at index 564 in NOT within range.
# Support Range from Index 574: [185.12289321899414, 181.4570933532715]
# Trough at index 560 in NOT within range.
# Trough at index 564 in NOT within range.
# Trough at index 570 in NOT within range.
# Support Range from Index 577: [184.7794969177246, 181.12049697875977]
# Trough at index 560 in NOT within range.
# Trough at index 564 in NOT within range.
# Trough at index 570 in NOT within range.
# Trough at index 574 in within range. Support Confirmed!
# Support Range from Index 584: [184.74919815063475, 181.09079818725587]
# Trough at index 564 in NOT within range.
# Trough at index 570 in NOT within range.
# Trough at index 574 in within range. Support Confirmed!
# Trough at index 577 in within range. Support Confirmed!
# Support Range from Index 589: [182.08279876708986, 178.4771987915039]
# Trough at index 570 in within range. Support Confirmed!
# Trough at index 574 in NOT within range.
# Trough at index 577 in NOT within range.
# Trough at index 584 in NOT within range.
# Support Range from Index 593: [183.97149383544922, 180.32849395751953]
# Trough at index 574 in within range. Support Confirmed!
# Trough at index 577 in NOT within range.
# Trough at index 584 in NOT within range.
# Trough at index 589 in NOT within range.
# Support Range from Index 605: [196.75809753417968, 192.86189758300782]
# Trough at index 589 in NOT within range.
# Trough at index 593 in NOT within range.
# Support Range from Index 608: [194.1219969177246, 190.27799697875977]
# Trough at index 589 in NOT within range.
# Trough at index 593 in NOT within range.
# Trough at index 605 in NOT within range.
# Support Range from Index 619: [184.325, 180.675]
# Trough at index 605 in NOT within range.
# Trough at index 608 in NOT within range.
# Support Range from Index 623: [179.65375, 176.09625]
# Trough at index 605 in NOT within range.
# Trough at index 608 in NOT within range.
# Trough at index 619 in within range. Support Confirmed!
# Support Range from Index 628: [174.75020431518556, 171.28980422973632]
# Trough at index 608 in NOT within range.
# Trough at index 619 in NOT within range.
# Trough at index 623 in NOT within range.
# Support Range from Index 633: [175.77535369873047, 172.29465362548828]
# Trough at index 619 in NOT within range.
# Trough at index 623 in NOT within range.
# Trough at index 628 in within range. Support Confirmed!
# Support Range from Index 643: [183.88050506591796, 180.2393069458008]
# Trough at index 623 in NOT within range.
# Trough at index 628 in NOT within range.
# Trough at index 633 in NOT within range.
# Support Range from Index 657: [159.44869506835937, 156.29129516601563]
# Trough at index 643 in NOT within range.
# Support Range from Index 662: [159.84119201660155, 156.67601989746095]
# Trough at index 643 in NOT within range.
# Trough at index 657 in NOT within range.
# Support Range from Index 668: [158.40335678100587, 155.2666566467285]
# Trough at index 657 in NOT within range.
# Trough at index 662 in within range. Support Confirmed!
# Support Range from Index 672: [159.26690246582032, 156.11310241699218]
# Trough at index 657 in NOT within range.
# Trough at index 662 in within range. Support Confirmed!
# Trough at index 668 in NOT within range.
# Support Range from Index 676: [153.98642532348632, 150.9371891784668]
# Trough at index 657 in NOT within range.
# Trough at index 662 in NOT within range.
# Trough at index 668 in NOT within range.
# Trough at index 672 in NOT within range.
# Support Range from Index 684: [149.2931524658203, 146.3368524169922]
# Trough at index 668 in NOT within range.
# Trough at index 672 in NOT within range.
# Trough at index 676 in NOT within range.
# Support Range from Index 696: [139.20830184936523, 136.45170181274415]
# Trough at index 676 in NOT within range.
# Trough at index 684 in NOT within range.
# Support Range from Index 706: [125.68944969177247, 123.20054969787597]
# Trough at index 696 in NOT within range.
# Support Range from Index 710: [126.59845123291015, 124.0915512084961]
# Trough at index 696 in NOT within range.
# Trough at index 706 in NOT within range.
# Support Range from Index 719: [114.30644485473633, 112.0429508972168]
# Trough at index 706 in NOT within range.
# Trough at index 710 in NOT within range.
# Support Range from Index 725: [112.81699691772461, 110.58299697875977]
# Trough at index 706 in NOT within range.
# Trough at index 710 in NOT within range.
# Trough at index 719 in within range. Support Confirmed!
# Support Range from Index 730: [112.16625923156738, 109.94514518737793]
# Trough at index 710 in NOT within range.
# Trough at index 719 in NOT within range.
# Trough at index 725 in within range. Support Confirmed!
# Support Range from Index 734: [121.42220123291015, 119.0178012084961]
# Trough at index 719 in NOT within range.
# Trough at index 725 in NOT within range.
# Trough at index 730 in NOT within range.
# Support Range from Index 741: [123.16031173706055, 120.72149368286132]
# Trough at index 725 in NOT within range.
# Trough at index 730 in NOT within range.
# Trough at index 734 in NOT within range.
# Support Range from Index 748: [107.2115015411377, 105.08850151062012]
# Trough at index 730 in NOT within range.
# Trough at index 734 in NOT within range.
# Trough at index 741 in NOT within range.
# Support Range from Index 760: [109.50187873840332, 107.33352470397949]
# Trough at index 741 in NOT within range.
# Trough at index 748 in NOT within range.
# Support Range from Index 766: [111.47370277404785, 109.26630271911621]
# Trough at index 748 in NOT within range.
# Trough at index 760 in NOT within range.
# Support Range from Index 781: [119.03850044250488, 116.68130241394043]
# Trough at index 766 in NOT within range.
# Support Range from Index 794: [124.44068893432618, 121.9765168762207]
# Trough at index 781 in NOT within range.
# Support Range from Index 801: [124.75145935058593, 122.28113342285157]
# Trough at index 781 in NOT within range.
# Trough at index 794 in NOT within range.
# Support Range from Index 818: [130.63845123291014, 128.0515512084961]
# Trough at index 801 in NOT within range.
# Support Range from Index 824: [126.49239784240723, 123.98759788513183]
# Trough at index 818 in NOT within range.
# Support Range from Index 843: [145.1774055480957, 142.30260543823243]
# Trough at index 824 in NOT within range.
# Support Range from Index 850: [145.34910369873046, 142.4709036254883]
# Trough at index 843 in NOT within range.
# Support Range from Index 856: [146.6519969177246, 143.74799697875977]
# Trough at index 843 in NOT within range.
# Trough at index 850 in NOT within range.
# Support Range from Index 872: [174.50779876708984, 171.0521987915039]
# Trough at index 856 in NOT within range.
# Support Range from Index 878: [168.44779876708984, 165.1121987915039]
# Trough at index 872 in NOT within range.
# Support Range from Index 886: [174.17955184936523, 170.73045181274415]
# Trough at index 872 in within range. Support Confirmed!
# Trough at index 878 in NOT within range.
# Support Range from Index 890: [176.22479568481447, 172.73519577026366]
# Trough at index 872 in within range. Support Confirmed!
# Trough at index 878 in NOT within range.
# Trough at index 886 in NOT within range.
# Support Range from Index 897: [192.30410171508788, 188.49609970092774]
# Trough at index 878 in NOT within range.
# Trough at index 886 in NOT within range.
# Trough at index 890 in NOT within range.
# Support Range from Index 904: [193.18774383544923, 189.36224395751952]
# Trough at index 886 in NOT within range.
# Trough at index 890 in NOT within range.
# Trough at index 897 in NOT within range.
# Support Range from Index 913: [196.75809753417968, 192.86189758300782]
# Trough at index 897 in NOT within range.
# Trough at index 904 in NOT within range.
# Support Range from Index 917: [193.62710678100586, 189.7929066467285]
# Trough at index 897 in NOT within range.
# Trough at index 904 in within range. Support Confirmed!
# Trough at index 913 in within range. Support Confirmed!
# Support Range from Index 936: [199.9699055480957, 196.01010543823242]
# Trough at index 917 in NOT within range.
# Support Range from Index 941: [198.80839630126954, 194.8715963745117]
# Trough at index 936 in NOT within range.
# Support Range from Index 948: [196.57630493164064, 192.68370483398436]
# Trough at index 936 in within range. Support Confirmed!
# Trough at index 941 in NOT within range.
# Support Range from Index 962: [216.36220123291017, 212.07780120849608]
# Trough at index 948 in NOT within range.
# Support Range from Index 971: [200.42309249877928, 196.4543183898926]
# Trough at index 962 in NOT within range.
# Support Range from Index 983: [199.2830975341797, 195.3368975830078]
# Trough at index 971 in NOT within range.
# Support Range from Index 992: [199.49751602172853, 195.5470701599121]
# Trough at index 983 in NOT within range.
# Support Range from Index 997: [204.0099055480957, 199.97010543823242]
# Trough at index 983 in NOT within range.
# Trough at index 992 in NOT within range.
# Support Range from Index 1012: [207.1834162902832, 203.08077438354493]
# Trough at index 992 in NOT within range.
# Trough at index 997 in NOT within range.
# Support Range from Index 1018: [207.77720123291016, 203.6628012084961]
# Trough at index 1012 in within range. Support Confirmed!
# Support Range from Index 1025: [204.7775, 200.7225]
# Trough at index 1012 in NOT within range.
# Trough at index 1018 in NOT within range.
# Support Range from Index 1030: [192.23330184936523, 188.42670181274414]
# Trough at index 1012 in NOT within range.
# Trough at index 1018 in NOT within range.
# Trough at index 1025 in within range. Support Confirmed!
# Support Range from Index 1039: [199.83860061645507, 195.88140060424806]
# Trough at index 1025 in NOT within range.
# Trough at index 1030 in NOT within range.
# Support Range from Index 1042: [196.95241958618163, 193.052371673584]
# Trough at index 1025 in NOT within range.
# Trough at index 1030 in NOT within range.
# Trough at index 1039 in within range. Support Confirmed!
# Support Range from Index 1046: [195.76819396972655, 191.89159606933595]
# Trough at index 1030 in NOT within range.
# Trough at index 1039 in NOT within range.
# Trough at index 1042 in within range. Support Confirmed!
# Support Range from Index 1053: [189.55679260253908, 185.80319274902342]
# Trough at index 1039 in NOT within range.
# Trough at index 1042 in NOT within range.
# Trough at index 1046 in within range. Support Confirmed!
# Support Range from Index 1056: [183.0725944519043, 179.44739456176757]
# Trough at index 1039 in NOT within range.
# Trough at index 1042 in NOT within range.
# Trough at index 1046 in NOT within range.
# Trough at index 1053 in within range. Support Confirmed!
# Support Range from Index 1067: [174.56839630126953, 171.11159637451172]
# Trough at index 1053 in NOT within range.
# Trough at index 1056 in NOT within range.
# Support Range from Index 1071: [175.53809555053712, 172.06209365844725]
# Trough at index 1053 in NOT within range.
# Trough at index 1056 in NOT within range.
# Trough at index 1067 in within range. Support Confirmed!
# Support Range from Index 1074: [175.235, 171.765]
# Trough at index 1056 in NOT within range.
# Trough at index 1067 in within range. Support Confirmed!
# Trough at index 1071 in within range. Support Confirmed!
# Support Range from Index 1091: [180.34357864379882, 176.7724186706543]
# Trough at index 1071 in NOT within range.
# Trough at index 1074 in NOT within range.
# Support Range from Index 1103: [182.7189958190918, 179.1007978820801]
# Trough at index 1091 in NOT within range.
# Support Range from Index 1109: [181.9111006164551, 178.30890060424804]
# Trough at index 1091 in within range. Support Confirmed!
# Trough at index 1103 in NOT within range.
# Support Range from Index 1112: [184.1735061645508, 180.52650604248046]
# Trough at index 1103 in NOT within range.
# Trough at index 1109 in NOT within range.
# Support Range from Index 1125: [198.94979568481446, 195.01019577026366]
# Trough at index 1109 in NOT within range.
# Trough at index 1112 in NOT within range.
# Support Range from Index 1129: [198.29330184936524, 194.36670181274414]
# Trough at index 1109 in NOT within range.
# Trough at index 1112 in NOT within range.
# Trough at index 1125 in within range. Support Confirmed!
# Support Range from Index 1139: [189.42550308227538, 185.67450302124024]
# Trough at index 1125 in NOT within range.
# Trough at index 1129 in NOT within range.
# Support Range from Index 1147: [194.62195739746093, 190.76805725097657]
# Trough at index 1129 in within range. Support Confirmed!
# Trough at index 1139 in NOT within range.
# Support Range from Index 1154: [189.04886444091798, 185.30532257080077]
# Trough at index 1139 in within range. Support Confirmed!
# Trough at index 1147 in NOT within range.
# Support Range from Index 1162: [194.4149055480957, 190.56510543823242]
# Trough at index 1147 in within range. Support Confirmed!
# Trough at index 1154 in NOT within range.
# Support Range from Index 1168: [197.35399383544922, 193.44599395751953]
# Trough at index 1154 in NOT within range.
# Trough at index 1162 in NOT within range.
# Support Range from Index 1183: [195.16220321655274, 191.29760513305663]
# Trough at index 1168 in NOT within range.
# Support Range from Index 1187: [195.65720123291015, 191.7828012084961]
# Trough at index 1168 in NOT within range.
# Trough at index 1183 in within range. Support Confirmed!
# Support Range from Index 1194: [189.17693298339844, 185.43085510253906]
# Trough at index 1183 in NOT within range.
# Trough at index 1187 in NOT within range.
# Support Range from Index 1200: [187.355, 183.645]
# Trough at index 1183 in NOT within range.
# Trough at index 1187 in NOT within range.
# Trough at index 1194 in within range. Support Confirmed!
# Support Range from Index 1207: [186.92070739746094, 183.21930725097656]
# Trough at index 1187 in NOT within range.
# Trough at index 1194 in within range. Support Confirmed!
# Trough at index 1200 in within range. Support Confirmed!
# Support Range from Index 1217: [189.1558348083496, 185.41017471313478]
# Trough at index 1200 in NOT within range.
# Trough at index 1207 in NOT within range.
# Support Range from Index 1227: [182.69889938354493, 179.08109939575195]
# Trough at index 1207 in NOT within range.
# Trough at index 1217 in NOT within range.
# Support Range from Index 1237: [185.3855030822754, 181.71450302124023]
# Trough at index 1217 in NOT within range.
# Trough at index 1227 in NOT within range.
# Support Range from Index 1244: [185.53699691772462, 181.86299697875975]
# Trough at index 1227 in NOT within range.
# Trough at index 1237 in within range. Support Confirmed!
# Support Range from Index 1249: [188.8599055480957, 185.12010543823243]
# Trough at index 1237 in NOT within range.
# Trough at index 1244 in NOT within range.
# Support Range from Index 1256: [186.1528971862793, 182.46670120239258]
# Trough at index 1237 in within range. Support Confirmed!
# Trough at index 1244 in within range. Support Confirmed!
# Trough at index 1249 in within range. Support Confirmed!
# Support Range from Index 1268: [163.84967575073242, 160.60512771606446]
# Trough at index 1249 in NOT within range.
# Trough at index 1256 in NOT within range.
# Support Range from Index 1278: [163.58970123291016, 160.3503012084961]
# Trough at index 1268 in within range. Support Confirmed!
# Support Range from Index 1284: [164.1755955505371, 160.92459365844726]
# Trough at index 1268 in within range. Support Confirmed!
# Trough at index 1278 in NOT within range.
# Support Range from Index 1291: [162.3069969177246, 159.09299697875977]
# Trough at index 1278 in within range. Support Confirmed!
# Trough at index 1284 in within range. Support Confirmed!
# Support Range from Index 1298: [155.17639938354492, 152.10359939575196]
# Trough at index 1278 in NOT within range.
# Trough at index 1284 in NOT within range.
# Trough at index 1291 in within range. Support Confirmed!
# Support Range from Index 1305: [161.75149383544922, 158.54849395751953]
# Trough at index 1291 in NOT within range.
# Trough at index 1298 in NOT within range.
# Support Range from Index 1313: [163.9230030822754, 160.67700302124024]
# Trough at index 1298 in NOT within range.
# Trough at index 1305 in within range. Support Confirmed!
# Support Range from Index 1317: [163.19580184936524, 159.96420181274414]
# Trough at index 1298 in NOT within range.
# Trough at index 1305 in within range. Support Confirmed!
# Trough at index 1313 in NOT within range.
# Support Range from Index 1321: [162.78169815063475, 159.55829818725587]
# Trough at index 1305 in within range. Support Confirmed!
# Trough at index 1313 in NOT within range.
# Trough at index 1317 in within range. Support Confirmed!
# Support Range from Index 1325: [161.56970123291015, 158.3703012084961]
# Trough at index 1305 in NOT within range.
# Trough at index 1313 in within range. Support Confirmed!
# Trough at index 1317 in within range. Support Confirmed!
# Trough at index 1321 in within range. Support Confirmed!
# Support Range from Index 1333: [162.2142820739746, 159.00211807250977]
# Trough at index 1313 in within range. Support Confirmed!
# Trough at index 1317 in within range. Support Confirmed!
# Trough at index 1321 in within range. Support Confirmed!
# Trough at index 1325 in within range. Support Confirmed!
# Support Range from Index 1348: [171.52830184936522, 168.13170181274415]
# Trough at index 1333 in NOT within range.
# Support Range from Index 1351: [173.93159820556642, 170.48740814208983]
# Trough at index 1333 in NOT within range.
# Trough at index 1348 in within range. Support Confirmed!
# Support Range from Index 1357: [168.30952789306642, 164.97666595458983]
# Trough at index 1348 in NOT within range.
# Trough at index 1351 in NOT within range.
# Support Range from Index 1365: [169.10429260253906, 165.75569274902344]
# Trough at index 1348 in NOT within range.
# Trough at index 1351 in NOT within range.
# Trough at index 1357 in within range. Support Confirmed!
# Support Range from Index 1368: [170.2355030822754, 166.86450302124024]
# Trough at index 1348 in NOT within range.
# Trough at index 1351 in NOT within range.
# Trough at index 1357 in within range. Support Confirmed!
# Trough at index 1365 in within range. Support Confirmed!
# Support Range from Index 1378: [169.66334030151367, 166.3036701965332]
# Trough at index 1365 in within range. Support Confirmed!
# Trough at index 1368 in within range. Support Confirmed!
# Support Range from Index 1383: [167.92037521362306, 164.59521926879881]
# Trough at index 1365 in NOT within range.
# Trough at index 1368 in NOT within range.
# Trough at index 1378 in NOT within range.
# Support Range from Index 1389: [168.01854568481446, 164.69144577026367]
# Trough at index 1378 in NOT within range.
# Trough at index 1383 in within range. Support Confirmed!
# Support Range from Index 1395: [169.175, 165.825]
# Trough at index 1378 in within range. Support Confirmed!
# Trough at index 1383 in within range. Support Confirmed!
# Trough at index 1389 in within range. Support Confirmed!
# Support Range from Index 1403: [175.58850616455078, 172.11150604248047]
# Trough at index 1383 in NOT within range.
# Trough at index 1389 in NOT within range.
# Trough at index 1395 in NOT within range.
# Support Range from Index 1424: [190.81929260253906, 187.04069274902344]
# Support Range from Index 1431: [187.62770431518555, 183.91230422973632]
# Trough at index 1424 in NOT within range.
# Support Range from Index 1438: [184.6886006164551, 181.03140060424803]
# Trough at index 1424 in NOT within range.
# Trough at index 1431 in NOT within range.
# Support Range from Index 1443: [186.57720321655273, 182.88260513305664]
# Trough at index 1424 in NOT within range.
# Trough at index 1431 in NOT within range.
# Trough at index 1438 in NOT within range.
# Support Range from Index 1451: [196.9657504272461, 193.06543853759766]
# Trough at index 1431 in NOT within range.
# Trough at index 1438 in NOT within range.
# Trough at index 1443 in NOT within range.
# Support Range from Index 1456: [200.92940246582032, 196.95060241699218]
# Trough at index 1438 in NOT within range.
# Trough at index 1443 in NOT within range.
# Trough at index 1451 in NOT within range.
# Support Range from Index 1460: [199.35380493164064, 195.40620483398436]
# Trough at index 1443 in NOT within range.
# Trough at index 1451 in NOT within range.
# Trough at index 1456 in NOT within range.
# Support Range from Index 1479: [217.02880493164062, 212.73120483398438]
# Trough at index 1460 in NOT within range.
# Support Range from Index 1487: [219.76589630126952, 215.41409637451173]
# Trough at index 1479 in NOT within range.
# Support Range from Index 1493: [222.13940246582033, 217.74060241699217]
# Trough at index 1479 in NOT within range.
# Trough at index 1487 in NOT within range.
# Support Range from Index 1496: [231.08800308227538, 226.51200302124025]
# Trough at index 1479 in NOT within range.
# Trough at index 1487 in NOT within range.
# Trough at index 1493 in NOT within range.
# Support Range from Index 1501: [226.85610061645508, 222.36390060424804]
# Trough at index 1487 in NOT within range.
# Trough at index 1493 in NOT within range.
# Trough at index 1496 in within range. Support Confirmed!
# Support Range from Index 1511: [246.56119506835938, 241.67879516601562]
# Trough at index 1493 in NOT within range.
# Trough at index 1496 in NOT within range.
# Trough at index 1501 in NOT within range.
# Support Range from Index 1514: [246.60664321899415, 241.72334335327147]
# Trough at index 1496 in NOT within range.
# Trough at index 1501 in NOT within range.
# Trough at index 1511 in NOT within range.
# Support Range from Index 1529: [261.3575964355469, 256.1821984863281]
# Trough at index 1511 in NOT within range.
# Trough at index 1514 in NOT within range.
# Support Range from Index 1533: [260.6860610961914, 255.52396087646486]
# Trough at index 1514 in NOT within range.
# Trough at index 1529 in within range. Support Confirmed!
# Support Range from Index 1536: [259.3276098632812, 254.19240966796875]
# Trough at index 1529 in NOT within range.
# Trough at index 1533 in NOT within range.
# Support Range from Index 1542: [258.3327438354492, 253.21724395751954]
# Trough at index 1529 in NOT within range.
# Trough at index 1533 in NOT within range.
# Trough at index 1536 in within range. Support Confirmed!
# Support Range from Index 1548: [265.09470123291015, 259.8453012084961]
# Trough at index 1529 in within range. Support Confirmed!
# Trough at index 1533 in NOT within range.
# Trough at index 1536 in NOT within range.
# Trough at index 1542 in NOT within range.
# Support Range from Index 1560: [264.52223022460936, 259.28416625976564]
# Trough at index 1542 in NOT within range.
# Trough at index 1548 in within range. Support Confirmed!
# Support Range from Index 1564: [262.0545913696289, 256.86539154052736]
# Trough at index 1548 in within range. Support Confirmed!
# Trough at index 1560 in within range. Support Confirmed!
# Support Range from Index 1571: [267.2358963012695, 261.94409637451173]
# Trough at index 1560 in NOT within range.
# Trough at index 1564 in NOT within range.
# Support Range from Index 1580: [251.81320739746093, 246.82680725097657]
# Trough at index 1560 in NOT within range.
# Trough at index 1564 in NOT within range.
# Trough at index 1571 in NOT within range.
# Support Range from Index 1584: [247.12679260253907, 242.23319274902343]
# Trough at index 1564 in NOT within range.
# Trough at index 1571 in NOT within range.
# Trough at index 1580 in within range. Support Confirmed!
# Support Range from Index 1595: [258.76201232910154, 253.63801208496093]
# Trough at index 1580 in NOT within range.
# Trough at index 1584 in NOT within range.
# Support Range from Index 1599: [258.96399383544923, 253.83599395751952]
# Trough at index 1580 in NOT within range.
# Trough at index 1584 in NOT within range.
# Trough at index 1595 in within range. Support Confirmed!
# Support Range from Index 1612: [265.6289828491211, 260.36900299072266]
# Trough at index 1595 in NOT within range.
# Trough at index 1599 in NOT within range.
# Support Range from Index 1615: [280.5737649536133, 275.01784881591794]
# Trough at index 1595 in NOT within range.
# Trough at index 1599 in NOT within range.
# Trough at index 1612 in NOT within range.
# Support Range from Index 1618: [281.285, 275.715]
# Trough at index 1599 in NOT within range.
# Trough at index 1612 in NOT within range.
# Trough at index 1615 in within range. Support Confirmed!
# Support Range from Index 1623: [285.2644024658203, 279.6156024169922]
# Trough at index 1612 in NOT within range.
# Trough at index 1615 in NOT within range.
# Trough at index 1618 in NOT within range.
# Support Range from Index 1631: [279.3558963012695, 273.8240963745117]
# Trough at index 1612 in NOT within range.
# Trough at index 1615 in within range. Support Confirmed!
# Trough at index 1618 in NOT within range.
# Trough at index 1623 in within range. Support Confirmed!
# Support Range from Index 1639: [272.7605975341797, 267.3593975830078]
# Trough at index 1623 in NOT within range.
# Trough at index 1631 in NOT within range.
# Support Range from Index 1648: [271.1263134765625, 265.7574755859375]
# Trough at index 1631 in NOT within range.
# Trough at index 1639 in within range. Support Confirmed!
# Support Range from Index 1653: [276.21983520507814, 270.75013549804686]
# Trough at index 1639 in NOT within range.
# Trough at index 1648 in NOT within range.
# Support Range from Index 1659: [273.7907864379883, 268.36918670654296]
# Trough at index 1639 in NOT within range.
# Trough at index 1648 in NOT within range.
# Trough at index 1653 in within range. Support Confirmed!
# Support Range from Index 1670: [283.44539764404294, 277.8326174926758]
# Trough at index 1653 in NOT within range.
# Trough at index 1659 in NOT within range.
# Support Range from Index 1680: [289.46095123291013, 283.7290512084961]
# Trough at index 1670 in NOT within range.
# Support Range from Index 1701: [259.23880950927736, 254.10536773681642]
# Support Range from Index 1707: [262.54951232910156, 257.35051208496094]
# Trough at index 1701 in within range. Support Confirmed!
# Support Range from Index 1715: [271.02339630126954, 265.6565963745117]
# Trough at index 1701 in NOT within range.
# Trough at index 1707 in NOT within range.
# Support Range from Index 1721: [267.91260986328126, 262.60740966796874]
# Trough at index 1701 in NOT within range.
# Trough at index 1707 in NOT within range.
# Trough at index 1715 in within range. Support Confirmed!
# Support Range from Index 1724: [266.5389938354492, 261.26099395751953]
# Trough at index 1707 in within range. Support Confirmed!
# Trough at index 1715 in NOT within range.
# Trough at index 1721 in NOT within range.
# Support Range from Index 1734: [259.72654876708987, 254.5834487915039]
# Trough at index 1715 in NOT within range.
# Trough at index 1721 in NOT within range.
# Trough at index 1724 in NOT within range.
# Support Range from Index 1739: [268.438415222168, 263.1228030395508]
# Trough at index 1721 in within range. Support Confirmed!
# Trough at index 1724 in within range. Support Confirmed!
# Trough at index 1734 in NOT within range.
# Support Range from Index 1742: [269.2054086303711, 263.87460845947265]
# Trough at index 1724 in within range. Support Confirmed!
# Trough at index 1734 in NOT within range.
# Trough at index 1739 in within range. Support Confirmed!
# Support Range from Index 1752: [263.3120364379883, 258.09793670654295]
# Trough at index 1734 in NOT within range.
# Trough at index 1739 in NOT within range.
# Trough at index 1742 in NOT within range.
# Support Range from Index 1758: [256.82785369873045, 251.74215362548827]
# Trough at index 1739 in NOT within range.
# Trough at index 1742 in NOT within range.
# Trough at index 1752 in NOT within range.
# Support Range from Index 1763: [256.7016036987305, 251.61840362548827]
# Trough at index 1752 in NOT within range.
# Trough at index 1758 in NOT within range.
# Support Range from Index 1771: [260.5749450683594, 255.41504516601563]
# Trough at index 1752 in NOT within range.
# Trough at index 1758 in NOT within range.
# Trough at index 1763 in NOT within range.
# Support Range from Index 1779: [246.44414566040038, 241.56406356811524]
# Trough at index 1763 in NOT within range.
# Trough at index 1771 in NOT within range.
# Support Range from Index 1784: [253.92410369873048, 248.89590362548827]
# Trough at index 1771 in NOT within range.
# Trough at index 1779 in NOT within range.
# Support Range from Index 1792: [249.17710678100585, 244.24290664672853]
# Trough at index 1779 in within range. Support Confirmed!
# Trough at index 1784 in NOT within range.
# Support Range from Index 1797: [247.1722561645508, 242.27775604248046]
# Trough at index 1779 in within range. Support Confirmed!
# Trough at index 1784 in NOT within range.
# Trough at index 1792 in within range. Support Confirmed!
# Support Range from Index 1802: [247.26820739746094, 242.37180725097656]
# Trough at index 1784 in NOT within range.
# Trough at index 1792 in within range. Support Confirmed!
# Trough at index 1797 in NOT within range.
# Support Range from Index 1805: [247.82369506835937, 242.91629516601563]
# Trough at index 1792 in within range. Support Confirmed!
# Trough at index 1797 in NOT within range.
# Trough at index 1802 in within range. Support Confirmed!
# Support Range from Index 1812: [245.0764938354492, 240.22349395751954]
# Trough at index 1792 in within range. Support Confirmed!
# Trough at index 1797 in within range. Support Confirmed!
# Trough at index 1802 in NOT within range.
# Trough at index 1805 in within range. Support Confirmed!
# Support Range from Index 1828: [231.06779876708984, 226.4921987915039]
# Trough at index 1812 in NOT within range.
# Support Range from Index 1833: [227.8155975341797, 223.3043975830078]
# Trough at index 1828 in within range. Support Confirmed!
# Support Range from Index 1842: [215.1034307861328, 210.8439569091797]
# Trough at index 1828 in NOT within range.
# Trough at index 1833 in NOT within range.
# Support Range from Index 1845: [217.21696243286132, 212.9156364440918]
# Trough at index 1828 in NOT within range.
# Trough at index 1833 in NOT within range.
# Trough at index 1842 in within range. Support Confirmed!
# Support Range from Index 1856: [235.41080184936524, 230.74920181274413]
# Trough at index 1842 in NOT within range.
# Trough at index 1845 in NOT within range.
# Support Range from Index 1861: [235.52190246582032, 230.85810241699218]
# Trough at index 1842 in NOT within range.
# Trough at index 1845 in NOT within range.
# Trough at index 1856 in within range. Support Confirmed!
# Support Range from Index 1869: [231.58562103271484, 226.9997671508789]
# Trough at index 1856 in NOT within range.
# Trough at index 1861 in NOT within range.
# Support Range from Index 1874: [233.1892056274414, 228.57159759521485]
# Trough at index 1856 in within range. Support Confirmed!
# Trough at index 1861 in NOT within range.
# Trough at index 1869 in within range. Support Confirmed!
# Support Range from Index 1885: [238.52664321899414, 233.8033433532715]
# Trough at index 1869 in NOT within range.
# Trough at index 1874 in NOT within range.
# Support Range from Index 1896: [259.81239013671876, 254.66759033203124]
# Trough at index 1885 in NOT within range.
# Support Range from Index 1901: [257.46414321899414, 252.3658433532715]
# Trough at index 1885 in NOT within range.
# Trough at index 1896 in within range. Support Confirmed!
# Support Range from Index 1906: [259.7720123291016, 254.62801208496094]
# Trough at index 1896 in NOT within range.
# Trough at index 1901 in within range. Support Confirmed!
# Support Range from Index 1915: [245.33910369873047, 240.48090362548828]
# Trough at index 1896 in NOT within range.
# Trough at index 1901 in NOT within range.
# Trough at index 1906 in NOT within range.
# Support Range from Index 1925: [248.1064938354492, 243.19349395751954]
# Trough at index 1906 in NOT within range.
# Trough at index 1915 in within range. Support Confirmed!
# Support Range from Index 1931: [254.5099055480957, 249.47010543823242]
# Trough at index 1915 in NOT within range.
# Trough at index 1925 in NOT within range.
# Support Range from Index 1941: [253.03529876708984, 248.0246987915039]
# Trough at index 1925 in NOT within range.
# Trough at index 1931 in NOT within range.
# Support Range from Index 1952: [276.3814389038086, 270.90853912353515]
# Trough at index 1941 in NOT within range.
# Support Range from Index 1956: [273.28236511230466, 267.87083312988284]
# Trough at index 1941 in NOT within range.
# Trough at index 1952 in NOT within range.
# Support Range from Index 1964: [275.33106109619143, 269.8789608764648]
# Trough at index 1952 in within range. Support Confirmed!
# Trough at index 1956 in NOT within range.
# Support Range from Index 1973: [278.7801889038086, 273.25978912353514]
# Trough at index 1956 in NOT within range.
# Trough at index 1964 in NOT within range.
# Support Range from Index 1980: [277.15410369873047, 271.6659036254883]
# Trough at index 1964 in NOT within range.
# Trough at index 1973 in within range. Support Confirmed!
# Support Range from Index 1987: [267.85201232910157, 262.54801208496093]
# Trough at index 1973 in NOT within range.
# Trough at index 1980 in within range. Support Confirmed!
# Support Range from Index 2001: [265.1078317260742, 259.85817169189454]
# Trough at index 1987 in within range. Support Confirmed!
# Support Range from Index 2008: [258.20649383544924, 253.09349395751954]
# Trough at index 2001 in within range. Support Confirmed!
# Support Range from Index 2015: [247.1874055480957, 242.2926054382324]
# Trough at index 2001 in NOT within range.
# Trough at index 2008 in NOT within range.
# Support Range from Index 2022: [249.5305975341797, 244.5893975830078]
# Trough at index 2008 in NOT within range.
# Trough at index 2015 in NOT within range.
# Support Range from Index 2026: [247.5005030822754, 242.59950302124022]
# Trough at index 2008 in NOT within range.
# Trough at index 2015 in NOT within range.
# Trough at index 2022 in within range. Support Confirmed!
# Support Range from Index 2032: [241.4405030822754, 236.65950302124023]
# Trough at index 2015 in NOT within range.
# Trough at index 2022 in NOT within range.
# Trough at index 2026 in NOT within range.
# ...
# Peak at index 4491 in within range. Resistance Confirmed!
# Peak at index 4498 in within range. Resistance Confirmed!
# Peak at index 4502 in NOT within range.
# Resistance Range from Index 4512: [296.2430975341797, 290.3768975830078]
# Peak at index 4498 in within range. Resistance Confirmed!
# Peak at index 4502 in NOT within range.
# Peak at index 4506 in NOT within range.
# Resistance Range from Index 4524: [281.9516036987305, 276.36840362548827]
# Peak at index 4506 in NOT within range.
# Peak at index 4512 in NOT within range.
# Resistance Range from Index 4532: [279.58820739746096, 274.05180725097654]
# Peak at index 4512 in NOT within range.
# Peak at index 4524 in NOT within range.
# Resistance Range from Index 4538: [263.1655975341797, 257.9543975830078]
# Peak at index 4524 in NOT within range.
# Peak at index 4532 in NOT within range.
# Resistance Range from Index 4544: [262.8070364379883, 257.60293670654295]
# Peak at index 4524 in NOT within range.
# Peak at index 4532 in NOT within range.
# Peak at index 4538 in within range. Resistance Confirmed!
# Resistance Range from Index 4554: [224.30080184936523, 219.85920181274415]
# Peak at index 4538 in NOT within range.
# Peak at index 4544 in NOT within range.
# Resistance Range from Index 4561: [232.805, 228.195]
# Peak at index 4544 in NOT within range.
# Peak at index 4554 in NOT within range.
# Resistance Range from Index 4564: [251.7930030822754, 246.80700302124023]
# Peak at index 4544 in NOT within range.
# Peak at index 4554 in NOT within range.
# Peak at index 4561 in within range. Resistance Confirmed!
# Resistance Range from Index 4575: [243.0969024658203, 238.2831024169922]
# Peak at index 4561 in NOT within range.
# Peak at index 4564 in NOT within range.
# Resistance Range from Index 4580: [251.59100616455078, 246.60900604248047]
# Peak at index 4561 in within range. Resistance Confirmed!
# Peak at index 4564 in within range. Resistance Confirmed!
# Peak at index 4575 in NOT within range.
# Resistance Range from Index 4587: [241.68794815063475, 236.90204818725587]
# Peak at index 4575 in within range. Resistance Confirmed!
# Peak at index 4580 in NOT within range.
# Resistance Range from Index 4598: [237.76914321899415, 233.06084335327148]
# Peak at index 4580 in NOT within range.
# Peak at index 4587 in within range. Resistance Confirmed!
# Resistance Range from Index 4601: [235.74914321899413, 231.0808433532715]
# Peak at index 4587 in NOT within range.
# Peak at index 4598 in within range. Resistance Confirmed!
# Resistance Range from Index 4607: [236.61279678344727, 231.92739486694336]
# Peak at index 4587 in NOT within range.
# Peak at index 4598 in within range. Resistance Confirmed!
# Peak at index 4601 in within range. Resistance Confirmed!
# Resistance Range from Index 4624: [281.22440246582033, 275.65560241699217]
# Peak at index 4607 in NOT within range.
# Resistance Range from Index 4630: [287.39548767089843, 281.70448791503907]
# Peak at index 4624 in NOT within range.
# Resistance Range from Index 4639: [285.20460632324216, 279.55699035644534]
# Peak at index 4624 in NOT within range.
# Peak at index 4630 in NOT within range.
# Resistance Range from Index 4661: [276.9117135620117, 271.42831329345705]
# Resistance Range from Index 4668: [278.271767578125, 272.761435546875]
# Peak at index 4661 in within range. Resistance Confirmed!
# Resistance Range from Index 4672: [283.4767135620117, 277.86331329345705]
# Peak at index 4661 in NOT within range.
# Peak at index 4668 in within range. Resistance Confirmed!
# Resistance Range from Index 4676: [273.58880493164065, 268.17120483398435]
# Peak at index 4661 in NOT within range.
# Peak at index 4668 in NOT within range.
# Peak at index 4672 in NOT within range.
# Resistance Range from Index 4684: [243.42707580566406, 238.60673767089844]
# Peak at index 4668 in NOT within range.
# Peak at index 4672 in NOT within range.
# Peak at index 4676 in NOT within range.
# Resistance Range from Index 4687: [241.73339630126952, 236.94659637451173]
# Peak at index 4668 in NOT within range.
# Peak at index 4672 in NOT within range.
# Peak at index 4676 in NOT within range.
# Peak at index 4684 in within range. Resistance Confirmed!
# Resistance Range from Index 4691: [235.50160568237305, 230.83820755004882]
# Peak at index 4672 in NOT within range.
# Peak at index 4676 in NOT within range.
# Peak at index 4684 in NOT within range.
# Peak at index 4687 in NOT within range.
# Resistance Range from Index 4695: [250.44566345214844, 245.48634338378906]
# Peak at index 4676 in NOT within range.
# Peak at index 4684 in NOT within range.
# Peak at index 4687 in NOT within range.
# Peak at index 4691 in NOT within range.
# Resistance Range from Index 4701: [223.79580184936523, 219.36420181274414]
# Peak at index 4684 in NOT within range.
# Peak at index 4687 in NOT within range.
# Peak at index 4691 in NOT within range.
# Peak at index 4695 in NOT within range.
# Resistance Range from Index 4707: [271.1648110961914, 265.79521087646486]
# Peak at index 4687 in NOT within range.
# Peak at index 4691 in NOT within range.
# Peak at index 4695 in NOT within range.
# Peak at index 4701 in NOT within range.
# Resistance Range from Index 4715: [254.9239938354492, 249.87599395751954]
# Peak at index 4695 in NOT within range.
# Peak at index 4701 in NOT within range.
# Peak at index 4707 in NOT within range.
# Resistance Range from Index 4722: [254.70179260253906, 249.65819274902344]
# Peak at index 4707 in NOT within range.
# Peak at index 4715 in NOT within range.
# Resistance Range from Index 4730: [256.6511006164551, 251.56890060424806]
# Peak at index 4715 in NOT within range.
# Peak at index 4722 in NOT within range.
# Resistance Range from Index 4735: [254.65099670410157, 249.60840270996093]
# Peak at index 4715 in NOT within range.
# Peak at index 4722 in NOT within range.
# Peak at index 4730 in NOT within range.
# Resistance Range from Index 4738: [253.30789520263673, 248.29189727783202]
# Peak at index 4722 in NOT within range.
# Peak at index 4730 in NOT within range.
# Peak at index 4735 in NOT within range.
# Resistance Range from Index 4743: [243.9655030822754, 239.13450302124022]
# Peak at index 4730 in NOT within range.
# Peak at index 4735 in NOT within range.
# Peak at index 4738 in NOT within range.
# Resistance Range from Index 4746: [244.19881591796874, 239.36319580078126]
# Peak at index 4730 in NOT within range.
# Peak at index 4735 in NOT within range.
# Peak at index 4738 in NOT within range.
# Peak at index 4743 in NOT within range.
# Resistance Range from Index 4759: [240.49110061645507, 235.72890060424805]
# Peak at index 4743 in within range. Resistance Confirmed!
# Peak at index 4746 in within range. Resistance Confirmed!
# Resistance Range from Index 4765: [257.1813444519043, 252.08864456176758]
# Peak at index 4746 in NOT within range.
# Peak at index 4759 in NOT within range.
# Resistance Range from Index 4768: [258.47414321899413, 253.3558433532715]
# Peak at index 4759 in NOT within range.
# Peak at index 4765 in within range. Resistance Confirmed!
# Resistance Range from Index 4771: [253.29789321899415, 248.28209335327148]
# Peak at index 4759 in NOT within range.
# Peak at index 4765 in NOT within range.
# Peak at index 4768 in NOT within range.
# Resistance Range from Index 4781: [287.02179260253905, 281.33819274902345]
# Peak at index 4765 in NOT within range.
# Peak at index 4768 in NOT within range.
# Peak at index 4771 in NOT within range.
# Resistance Range from Index 4785: [287.72375, 282.02625]
# Peak at index 4765 in NOT within range.
# Peak at index 4768 in NOT within range.
# Peak at index 4771 in NOT within range.
# Peak at index 4781 in within range. Resistance Confirmed!
# Resistance Range from Index 4792: [288.7377877807617, 283.02020782470703]
# Peak at index 4781 in within range. Resistance Confirmed!
# Peak at index 4785 in within range. Resistance Confirmed!
# Resistance Range from Index 4798: [289.72818450927736, 283.9909927368164]
# Peak at index 4781 in within range. Resistance Confirmed!
# Peak at index 4785 in within range. Resistance Confirmed!
# Peak at index 4792 in NOT within range.
# Resistance Range from Index 4807: [289.08220123291017, 283.3578012084961]
# Peak at index 4792 in NOT within range.
# Peak at index 4798 in NOT within range.
# Resistance Range from Index 4817: [295.12201232910155, 289.27801208496095]
# Peak at index 4798 in within range. Resistance Confirmed!
# Peak at index 4807 in NOT within range.
# Resistance Range from Index 4825: [284.6482864379883, 279.01168670654295]
# Peak at index 4807 in NOT within range.
# Peak at index 4817 in NOT within range.
# Resistance Range from Index 4834: [278.0025, 272.4975]
# Peak at index 4817 in NOT within range.
# Peak at index 4825 in NOT within range.
# Resistance Range from Index 4843: [289.5367135620117, 283.80331329345705]
# Peak at index 4825 in NOT within range.
# Peak at index 4834 in NOT within range.
# Resistance Range from Index 4848: [287.73891479492187, 282.04111450195313]
# Peak at index 4834 in NOT within range.
# Peak at index 4843 in within range. Resistance Confirmed!
# Resistance Range from Index 4852: [300.8789938354492, 294.92099395751956]
# Peak at index 4834 in NOT within range.
# Peak at index 4843 in NOT within range.
# Peak at index 4848 in NOT within range.
# Resistance Range from Index 4855: [301.08273223876955, 295.1206979370117]
# Peak at index 4843 in NOT within range.
# Peak at index 4848 in NOT within range.
# Peak at index 4852 in within range. Resistance Confirmed!
# Resistance Range from Index 4862: [321.8061950683594, 315.4337951660156]
# Peak at index 4843 in NOT within range.
# Peak at index 4848 in NOT within range.
# Peak at index 4852 in NOT within range.
# Peak at index 4855 in NOT within range.
# Resistance Range from Index 4866: [332.7344024658203, 326.1456024169922]
# Peak at index 4848 in NOT within range.
# Peak at index 4852 in NOT within range.
# Peak at index 4855 in NOT within range.
# Peak at index 4862 in NOT within range.
# Resistance Range from Index 4871: [346.15953033447266, 339.3048861694336]
# Peak at index 4852 in NOT within range.
# Peak at index 4855 in NOT within range.
# Peak at index 4862 in NOT within range.
# Peak at index 4866 in NOT within range.
# Resistance Range from Index 4874: [350.19407470703123, 343.25953857421877]
# Peak at index 4855 in NOT within range.
# Peak at index 4862 in NOT within range.
# Peak at index 4866 in NOT within range.
# Peak at index 4871 in within range. Resistance Confirmed!
# Resistance Range from Index 4879: [345.86945739746096, 339.02055725097654]
# Peak at index 4862 in NOT within range.
# Peak at index 4866 in NOT within range.
# Peak at index 4871 in NOT within range.
# Peak at index 4874 in NOT within range.
# Resistance Range from Index 4883: [346.1556774902344, 339.3011096191406]
# Peak at index 4866 in NOT within range.
# Peak at index 4871 in NOT within range.
# Peak at index 4874 in NOT within range.
# Peak at index 4879 in within range. Resistance Confirmed!
# Resistance Range from Index 4889: [352.2980975341797, 345.3218975830078]
# Peak at index 4871 in within range. Resistance Confirmed!
# Peak at index 4874 in within range. Resistance Confirmed!
# Peak at index 4879 in within range. Resistance Confirmed!
# Peak at index 4883 in within range. Resistance Confirmed!
# Resistance Range from Index 4893: [342.0314389038086, 335.2585391235352]
# Peak at index 4874 in NOT within range.
# Peak at index 4879 in NOT within range.
# Peak at index 4883 in NOT within range.
# Peak at index 4889 in NOT within range.
# Resistance Range from Index 4897: [345.34929260253904, 338.51069274902346]
# Peak at index 4879 in NOT within range.
# Peak at index 4883 in NOT within range.
# Peak at index 4889 in NOT within range.
# Peak at index 4893 in within range. Resistance Confirmed!
# Resistance Range from Index 4901: [353.86358520507815, 346.85638549804685]
# Peak at index 4883 in NOT within range.
# Peak at index 4889 in within range. Resistance Confirmed!
# Peak at index 4893 in NOT within range.
# Peak at index 4897 in NOT within range.
# Resistance Range from Index 4907: [349.83875, 342.91125]
# Peak at index 4889 in within range. Resistance Confirmed!
# Peak at index 4893 in NOT within range.
# Peak at index 4897 in within range. Resistance Confirmed!
# Peak at index 4901 in NOT within range.
# Resistance Range from Index 4916: [348.58635986328125, 341.68365966796875]
# Peak at index 4897 in within range. Resistance Confirmed!
# Peak at index 4901 in NOT within range.
# Peak at index 4907 in NOT within range.
# Resistance Range from Index 4921: [342.57179260253906, 335.78819274902344]
# Peak at index 4901 in NOT within range.
# Peak at index 4907 in within range. Resistance Confirmed!
# Peak at index 4916 in NOT within range.
# Resistance Range from Index 4929: [365.1226748657227, 357.8925228881836]
# Peak at index 4916 in NOT within range.
# Peak at index 4921 in NOT within range.
# Resistance Range from Index 4932: [366.3785171508789, 359.12349700927734]
# Peak at index 4916 in NOT within range.
# Peak at index 4921 in NOT within range.
# Peak at index 4929 in within range. Resistance Confirmed!
# Resistance Range from Index 4936: [366.2461950683594, 358.9937951660156]
# Peak at index 4916 in NOT within range.
# Peak at index 4921 in NOT within range.
# Peak at index 4929 in within range. Resistance Confirmed!
# Peak at index 4932 in within range. Resistance Confirmed!
# Resistance Range from Index 4939: [360.48921356201174, 353.350813293457]
# Peak at index 4921 in NOT within range.
# Peak at index 4929 in NOT within range.
# Peak at index 4932 in NOT within range.
# Peak at index 4936 in NOT within range.
# Resistance Range from Index 4947: [365.4735610961914, 358.23646087646483]
# Peak at index 4929 in within range. Resistance Confirmed!
# Peak at index 4932 in within range. Resistance Confirmed!
# Peak at index 4936 in within range. Resistance Confirmed!
# Peak at index 4939 in within range. Resistance Confirmed!
# Resistance Range from Index 4963: [356.05187744140625, 349.00134521484375]
# Peak at index 4947 in NOT within range.
# Resistance Range from Index 4971: [336.1835610961914, 329.52646087646485]
# Peak at index 4963 in NOT within range.
# Resistance Range from Index 4982: [298.2025, 292.2975]
# Peak at index 4963 in NOT within range.
# Peak at index 4971 in NOT within range.
# Resistance Range from Index 4996: [317.00505798339844, 310.72773010253906]
# Peak at index 4982 in NOT within range.
# Resistance Range from Index 5002: [329.4114938354492, 322.88849395751953]
# Peak at index 4982 in NOT within range.
# Peak at index 4996 in NOT within range.
# Resistance Range from Index 5011: [329.6639938354492, 323.13599395751953]
# Peak at index 4996 in NOT within range.
# Peak at index 5002 in NOT within range.
# Resistance Range from Index 5020: [335.48160369873045, 328.8384036254883]
# Peak at index 5002 in within range. Resistance Confirmed!
# Peak at index 5011 in NOT within range.
# Resistance Range from Index 5023: [328.60350616455077, 322.0965060424805]
# Peak at index 5011 in within range. Resistance Confirmed!
# Peak at index 5020 in within range. Resistance Confirmed!
# Resistance Range from Index 5039: [328.23989013671877, 321.74009033203123]
# Peak at index 5020 in within range. Resistance Confirmed!
# Peak at index 5023 in NOT within range.
# Resistance Range from Index 5044: [325.31595123291015, 318.8740512084961]
# Peak at index 5039 in within range. Resistance Confirmed!
# Resistance Range from Index 5047: [326.57845123291014, 320.1115512084961]
# Peak at index 5039 in within range. Resistance Confirmed!
# Peak at index 5044 in within range. Resistance Confirmed!
# Resistance Range from Index 5052: [356.5451647949219, 349.4848645019531]
# Peak at index 5039 in NOT within range.
# Peak at index 5044 in NOT within range.
# Peak at index 5047 in NOT within range.
# Resistance Range from Index 5058: [352.1970913696289, 345.22289154052737]
# Peak at index 5039 in NOT within range.
# Peak at index 5044 in NOT within range.
# Peak at index 5047 in NOT within range.
# Peak at index 5052 in NOT within range.
# Resistance Range from Index 5072: [330.8658963012695, 324.31409637451173]
# Peak at index 5052 in NOT within range.
# Peak at index 5058 in NOT within range.
# Resistance Range from Index 5079: [329.0276889038086, 322.51228912353514]
# Peak at index 5072 in within range. Resistance Confirmed!
